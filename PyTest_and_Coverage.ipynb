# %% [markdown]
# # PyTest

# %%
# !pip install pytest
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# Verify installation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Project Structure
# -----------------
# This project has two modules:
# * `src.calc_func` contains math functions.
# * `src.calc_class` contains a basic Calculator class.
#
# Test modules are placed under the `tests` directory.
# Note that `tests` is *not* a Python package, It doesn't need to be shipped as part of final package but generally used for interal testing.

# %% [markdown]
# Running Tests
# -------------
#
# * `python -m pytest` to discover and run all tests from the current directory
# * `python -m pytest -v` to explicitly print the result of each test as it is run
# * `python -m pytest tests/test_calc_func.py` to run only the math function tests
# * `python -m pytest tests/test_calc_class.py` to run only the Calculator class tests
# * `python -m pytest -k dividetestsgroup` to run a group of testcases that are marked with the groupname as dividetestsgroup
# * `python -m pytest -h`  for command line help
#
# It is also possible to run pytest directly with the "pytest" or "py.test" command,
# instead of using the longer "python -m pytest" module form. However, the shorter
# command does *not* append the current directory path to *PYTHONPATH*.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Coverage
#
# `Coverage.py` is a tool for measuring code coverage of Python programs.
#
# It monitors your program, noting which parts of the code have been executed, then analyzes the source to identify code that could have been executed but was not.
#
# Coverage measurement is typically used to gauge the effectiveness of tests.
#
# It can show which parts of your code are being exercised by tests, and which are not.

# %%
# !pip install coverage
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   WARNING: The scripts coverage-3.9.exe, coverage.exe and coverage3.exe are installed in 'C:\Users\km140\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# Verify installation:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Running Coverage reports
#
# `python -m coverage run --source=src/ -m pytest -v` to run the coverage on the selected folder, the tests will automatically run since `pytest` option is given. It does not display any output, you must run `coverage report` to view the report.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `python -m coverage report` to view the report of the last coverage run.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# `python -m coverage html` to view the report in html format.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
